# %%
import pandas as pd
import numpy as np
from statsmodels.stats import weightstats as stests
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../complete_site_info.xlsx',index_col = False)

# %%
df.drop('Unnamed: 0', inplace= True, axis=1)

# %%
df.head()
# Out:
#    Model_number       Date                    Site_Name  Israelis_Count  \
# 0             5 2016-01-01  Alexander Stream-Bet Yannai               7
# 1             6 2016-01-01                    Apollonia              16
# 2             3 2016-01-01                        Arbel               8
# 3             5 2016-01-01                        Avdat              13
# 4             5 2016-01-01                  Ayun Stream               6
#
#    Tourists_Count  Total  is_weekend  operations  is_jewish_holiday  \
# 0               0      7           1           0                  0
# 1               0     16           1           0                  0
# 2              52     60           1           0                  0
# 3              26     39           1           0                  0
# 4               0      6           1           0                  0
#
#    is_jewish_vacation  ...  Haifa_so2  Ashkelon_so2  Beer-Sheva_so2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109108 entries, 0 to 109107
# Data columns (total 69 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Model_number          109108 non-null  int64
#  1   Date                  109108 non-null  datetime64[ns]
#  2   Site_Name             109108 non-null  object
#  3   Israelis_Count        109108 non-null  int64
#  4   Tourists_Count        109108 non-null  int64
#  5   Total                 109108 non-null  int64
#  6   is_weekend            109108 non-null  int64
#  7   operations            109108 non-null  int64
#  8   is_jewish_holiday     109108 non-null  int64
#  9   is_jewish_vacation    109108 non-null  int64
#  10  is_muslims_holiday    109108 non-null  int64
#  11  is_muslims_vacation   109108 non-null  int64
#  12  camping               109108 non-null  int64
#  13  special_activity      109108 non-null  int64
# ...

# %%
plt.hist(df.Israelis_Count, color='b',edgecolor='black', linewidth=1.2)
# Out:
# (array([1.09034e+05, 2.50000e+01, 1.00000e+01, 9.00000e+00, 1.00000e+01,
#         6.00000e+00, 4.00000e+00, 6.00000e+00, 2.00000e+00, 2.00000e+00]),
#  array([     0.,  11002.,  22004.,  33006.,  44008.,  55010.,  66012.,
#          77014.,  88016.,  99018., 110020.]),
#  <BarContainer object of 10 artists>)
