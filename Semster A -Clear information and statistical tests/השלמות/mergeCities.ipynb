# %%
import pandas as pd

# %%
df1=pd.read_excel("info_site_complete_with_models_and_nulls.xlsx")
df1
# Out:
#         Model_number       Date                    Site_Name  Israelis_Count  \
# 0                  5 2016-01-01  Alexander Stream-Bet Yannai               7
# 1                  6 2016-01-01                    Apollonia              16
# 2                  3 2016-01-01                        Arbel               8
# 3                  5 2016-01-01                        Avdat              13
# 4                  5 2016-01-01                  Ayun Stream               6
# ...              ...        ...                          ...             ...
# 109103             3 2021-08-11         The Majrase – Betiha             744
# 109104             0 2021-08-11                   The Masada             508
# 109105             5 2021-08-11                      Tzipori             102
# 109106             3 2021-08-11                       Yehiam              92
# 109107             5 2021-08-11                     Yehudiya             694
#
# ...

# %%
df2=pd.read_excel("cities_to_merge.xlsx")
df2
# Out:
#            Date  Tel_Aviv-Yafo_pm10  Jerusalem_pm10  Haifa_pm10  \
# 0    2016-01-01                64.1            25.6        23.3
# 1    2016-02-01                63.1            25.1        23.8
# 2    2016-03-01                82.3            99.1        27.1
# 3    2016-04-01                75.2            66.6        36.6
# 4    2016-05-01               105.6           177.4        40.3
# ...         ...                 ...             ...         ...
# 2177 2021-12-17                58.9            51.3        59.0
# 2178 2021-12-18                82.2            48.8        44.7
# 2179 2021-12-19               162.7           219.2       129.9
# 2180 2021-12-20                93.7            68.5        66.7
# 2181 2021-12-21                93.7            68.5        66.7
#
#       Ashkelon_pm10  Beer-Sheva_pm10  Eilat_pm10  Qiryat Shemona_pm10  \
# 0              11.2              4.9        24.1                 24.1
# ...

# %%
df1=df1.merge(right=df2,on="Date")
df1
# Out:
#         Model_number       Date                    Site_Name  Israelis_Count  \
# 0                  5 2016-01-01  Alexander Stream-Bet Yannai               7
# 1                  6 2016-01-01                    Apollonia              16
# 2                  3 2016-01-01                        Arbel               8
# 3                  5 2016-01-01                        Avdat              13
# 4                  5 2016-01-01                  Ayun Stream               6
# ...              ...        ...                          ...             ...
# 109103             3 2021-08-11         The Majrase – Betiha             744
# 109104             0 2021-08-11                   The Masada             508
# 109105             5 2021-08-11                      Tzipori             102
# 109106             3 2021-08-11                       Yehiam              92
# 109107             5 2021-08-11                     Yehudiya             694
#
# ...

# %%
df1.to_excel("complete_maybe.xlsx")
